# %%
import warnings
warnings.filterwarnings('ignore')

# %%
cd ..
# Out:
# /home/jovyan/gt_ml_project_1

# %%
# %run __init__.py

# %%
# %run src/load_data.py

# %%
from lib.benchmark import run_model, run_experiment, plot_results

# %% [markdown]
# # Models To Test

# %%
models = ['svm', 'knn', 'neural_net', 'boosting', 'decision tree']

# %% [markdown]
# # Madelon Data Benchmarking

# %%
test_results_madelon, tests = run_experiment(data, "madelon")
# Out:
# 100%|██████████| 18/18 [00:21<00:00,  1.18s/it]
# 100%|██████████| 18/18 [00:24<00:00,  1.34s/it]
# 100%|██████████| 18/18 [00:27<00:00,  1.52s/it]
# 100%|██████████| 18/18 [00:25<00:00,  1.43s/it]
# 100%|██████████| 18/18 [00:27<00:00,  1.52s/it]
# 100%|██████████| 18/18 [00:26<00:00,  1.45s/it]
# 100%|██████████| 18/18 [00:02<00:00,  6.60it/s]
# 100%|██████████| 18/18 [00:18<00:00,  1.05s/it]
# 100%|██████████| 18/18 [00:19<00:00,  1.08s/it]
# 100%|██████████| 18/18 [00:13<00:00,  1.33it/s]
# 100%|██████████| 18/18 [00:13<00:00,  1.31it/s]
# 100%|██████████| 18/18 [00:14<00:00,  1.23it/s]
# 100%|██████████| 18/18 [00:02<00:00,  8.24it/s]
# 100%|██████████| 18/18 [00:02<00:00,  8.17it/s]
# 100%|██████████| 18/18 [00:02<00:00,  6.28it/s]

# %%
plot_results(test_results_madelon, tests, models, train=True, ylim=(0.2,1))

# %% [markdown]
# # Adult

# %%
test_results_adult, tests = run_experiment(data, "adult")
# Out:
# 100%|██████████| 18/18 [06:50<00:00, 22.80s/it]
# 100%|██████████| 18/18 [06:19<00:00, 21.08s/it]
# 100%|██████████| 18/18 [06:31<00:00, 21.77s/it]
# 100%|██████████| 18/18 [03:32<00:00, 11.81s/it]
# 100%|██████████| 18/18 [10:47<00:00, 35.99s/it]
# 100%|██████████| 18/18 [10:22<00:00, 34.57s/it]
# 100%|██████████| 18/18 [00:12<00:00,  1.45it/s]
# 100%|██████████| 18/18 [02:28<00:00,  8.25s/it]
# 100%|██████████| 18/18 [01:59<00:00,  6.65s/it]
# 100%|██████████| 18/18 [00:10<00:00,  1.73it/s]
# 100%|██████████| 18/18 [00:11<00:00,  1.63it/s]
# 100%|██████████| 18/18 [00:12<00:00,  1.48it/s]
# 100%|██████████| 18/18 [00:01<00:00, 10.92it/s]
# 100%|██████████| 18/18 [00:01<00:00,  9.09it/s]
# 100%|██████████| 18/18 [00:03<00:00,  4.87it/s]

# %%
plot_results(test_results_adult, tests, models, train=True, ylim=(0.2, 1))

# %%
test_results_adult.columns
# Out:
# Index(['accuracy_test_score', 'accuracy_train_score', 'f1_test_score',
#        'f1_train_score', 'fit_time', 'model_name', 'n', 'n_pcnt',
#        'test_pred_time', 'train_pred_time'],
#       dtype='object')

# %%
whos DataFrame
# Out:
# Variable               Type         Data/Info
# ---------------------------------------------
# adult_test_data        DataFrame           age          workc<...>n[7490 rows x 14 columns]
# adult_train_data       DataFrame           age          workc<...>[25071 rows x 14 columns]
# madelon_test_data      DataFrame         0    1    2    3    <...>n[600 rows x 500 columns]
# madelon_train_data     DataFrame          0    1    2    3   <...>[2000 rows x 500 columns]
# test_results_adult     DataFrame                             <...>\n[270 rows x 10 columns]
# test_results_madelon   DataFrame                             <...>\n[270 rows x 10 columns]

# %%
test_results_adult.to_pickle("results/Benchmark_5_adult.p")
test_results_madelon.to_pickle("results/Benchmark_5_madelon.p")
