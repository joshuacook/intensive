# %%
cd ..
# Out:
# /home/jovyan/jcook95

# %%
# %run __init__.py

# %%
# %run src/load_data.py

# %% [markdown]
# ## Adult

# %%
fig = plt.figure(figsize=(20,6))
sns.countplot(adult_train_labels)

# %%
from sklearn.metrics import accuracy_score, f1_score

# %% [markdown]
# ### Naive Benchmark
#
# This is our naive benchmark: *everyone makes more than $50k*

# %%
guess_true_for_everyone = adult_train_labels**0

# %% [markdown]
# ### Fundamental Question: *Who makes more than $50k?*

# %%
accuracy_score(adult_train_labels, guess_true_for_everyone)
# Out:
# 0.24079613896533844

# %%
f1_score(adult_train_labels, guess_true_for_everyone)
# Out:
# 0.38813167030988815

# %% [markdown]
# ## Madelon

# %%
fig = plt.figure(figsize=(20,6))
sns.countplot(madelon_train_labels)

# %% [markdown]
# ### Naive Benchmark
#
# This is our naive benchmark: *everything is 1*

# %%
guess_true_for_all = madelon_train_labels**0

# %% [markdown]
# ### Fundamental Question: *Which class is each point?*

# %%
accuracy_score(madelon_train_labels, guess_true_for_all)
# Out:
# 0.5

# %%
f1_score(madelon_train_labels, guess_true_for_all)
# Out:
# 0.66666666666666663

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split

# %%
for col in madelon_train_data.columns:
# Out:
# Variable                    Type         Data/Info
# --------------------------------------------------
# MinMaxScaler                type         <class 'sklearn.preprocessing.data.MinMaxScaler'>
# StandardScaler              type         <class 'sklearn.preproces<...>ing.data.StandardScaler'>
# adult_feature_engineering   function     <function adult_feature_e<...>eering at 0x7fe84ee57ea0>
# adult_test_data             DataFrame           age          workc<...>n[7490 rows x 14 columns]
# adult_test_labels           Series       17198    1\n15457    0\n5<...>ength: 7490, dtype: int64
# adult_train_data            DataFrame           age          workc<...>[25071 rows x 14 columns]
# adult_train_labels          Series       26490    1\n6476     0\n2<...>ngth: 25071, dtype: int64
# data                        dict         n=2
# display                     function     <function display at 0x7fe88b812a60>
# get_ipython                 function     <function get_ipython at 0x7fe88e3e4c80>
# madelon_test_data           DataFrame         0    1    2    3    <...>n[600 rows x 500 columns]
# madelon_test_labels         Series       0     -1\n1     -1\n2    <...>Length: 600, dtype: int64
# madelon_train_data          DataFrame          0    1    2    3   <...>[2000 rows x 500 columns]
# madelon_train_labels        Series       0      -1\n1      -1\n2  <...>ength: 2000, dtype: int64
# make_pipeline               function     <function make_pipeline at 0x7fe84dfe5ae8>
# np                          module       <module 'numpy' from '/op<...>kages/numpy/__init__.py'>
# pd                          module       <module 'pandas' from '/o<...>ages/pandas/__init__.py'>
# plt                         module       <module 'matplotlib.pyplo<...>es/matplotlib/pyplot.py'>
# sns                         module       <module 'seaborn' from '/<...>ges/seaborn/__init__.py'>
# stats                       module       <module 'scipy.stats' fro<...>scipy/stats/__init__.py'>
# sys                         module       <module 'sys' (built-in)>
