# %%
cd ..
# Out:
# /Users/Amar/Dropbox/Computer_Science/GATECH-OMSCS/7641_ML/GT_ML_Project_1

# %%
# %run __init__.py

# %%
# %run src/load_data.py

# %%
from lib.benchmark import run_model, run_experiment, plot_results

# %% [markdown]
# # Models To Test

# %%
models = ['svm', 'knn', 'neural_net', 'boosting', 'decision tree']

# %% [markdown]
# # Madelon Data Benchmarking

# %%
test_results_madelon, tests = run_experiment(data, "madelon")
# Out:
#   0%|          | 0/18 [00:00<?, ?it/s]/Users/Amar/miniconda3/lib/python3.5/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ...
#   0%|          | 0/18 [00:00<?, ?it/s]/Users/Amar/miniconda3/lib/python3.5/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/Amar/miniconda3/lib/python3.5/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ...

# %%
plot_results(test_results_madelon, tests, models)
# Out:
# /Users/Amar/miniconda3/lib/python3.5/site-packages/matplotlib/axes/_base.py:3291: UserWarning: Attempted to set non-positive ylimits for log-scale axis; invalid limits will be ignored.
#   'Attempted to set non-positive ylimits for log-scale axis; '

# %% [markdown]
# # Adult

# %%
test_results_adult, tests = run_experiment(data, "adult")
# Out:
# ...
#   0%|          | 0/18 [00:00<?, ?it/s]/Users/Amar/miniconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#   6%|▌         | 1/18 [00:00<00:05,  3.22it/s]/Users/Amar/miniconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  11%|█         | 2/18 [00:00<00:06,  2.41it/s]/Users/Amar/miniconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ...

# %%
plot_results(test_results_adult, tests, models)
# Out:
# /Users/Amar/miniconda3/lib/python3.5/site-packages/matplotlib/axes/_base.py:3291: UserWarning: Attempted to set non-positive ylimits for log-scale axis; invalid limits will be ignored.
#   'Attempted to set non-positive ylimits for log-scale axis; '

# %%
test_results_adult.columns
# Out:
# Index(['accuracy_test_score', 'accuracy_train_score', 'f1_test_score',
#        'f1_train_score', 'fit_time', 'model_name', 'n', 'n_pcnt',
#        'test_pred_time', 'train_pred_time'],
#       dtype='object')

# %%
test_results_adult.fit_time
# Out:
# boosting basic 1                0.112001
# svm scaled 1                  0.00677896
# boosting deskewed 1             0.102861
# decision tree deskewed 1      0.00237703
# knn basic 1                   0.00140095
# boosting scaled 1               0.090359
# neural_net scaled 1             0.248053
# knn deskewed 1                0.00215793
# neural_net deskewed 1           0.200875
# svm deskewed 1                  0.007936
# knn scaled 1                  0.00135803
# decision tree basic 1         0.00111294
# neural_net basic 1             0.0567791
# svm basic 1                   0.00407195
# decision tree scaled 1        0.00197482
# neural_net scaled 2             0.447232
# decision tree scaled 2        0.00355315
# boosting scaled 2               0.086621
# decision tree basic 2           0.002249
# decision tree deskewed 2      0.00459385
# knn basic 2                   0.00123906
# neural_net deskewed 2           0.386523
# svm deskewed 2                 0.0157561
# ...
