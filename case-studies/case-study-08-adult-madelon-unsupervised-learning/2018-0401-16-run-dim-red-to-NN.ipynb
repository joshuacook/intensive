# %%
cd ..
# Out:
# /home/jovyan

# %%
# %run __init__.py

# %%
run src/load_data.py

# %%
adult_train_scaled = data['adult']['train']['scaled']
madelon_train_scaled = data['madelon']['train']['scaled']
adult_train_gelman = data['adult']['train']['gelman_scaled']

# %%
from lib.benchmark import run_experiment_2, pipeline_basic
from sklearn.neural_network import MLPClassifier

# %%
adult_nn_scaled, _ = run_experiment_2(adult_train_scaled, adult_train_labels, tests=[('neural_net', 'basic', pipeline_basic(MLPClassifier))])
adult_nn_gelman, _ = run_experiment_2(adult_train_gelman, adult_train_labels, tests=[('neural_net', 'basic', pipeline_basic(MLPClassifier))])
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]/opt/conda/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ...
# 100%|██████████| 4/4 [00:31<00:00,  7.97s/it]

# %%
adult_nn_ic, _ = run_experiment_2(adult_final_ic, adult_train_labels, tests=[('neural_net', 'basic', pipeline_basic(MLPClassifier))])
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]/opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 100%|██████████| 4/4 [00:15<00:00,  3.85s/it]

# %%
adult_nn_rp, _ = run_experiment_2(adult_final_rp, adult_train_labels, tests=[('neural_net', 'basic', pipeline_basic(MLPClassifier))])
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]/opt/conda/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# 100%|██████████| 4/4 [00:17<00:00,  4.40s/it]

# %%
adult_nn_pca, _ = run_experiment_2(adult_final_pca, adult_train_labels, tests=[('neural_net', 'basic', pipeline_basic(MLPClassifier))])
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]/opt/conda/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# 100%|██████████| 4/4 [00:10<00:00,  2.54s/it]

# %%
adult_nn_sfm, _ = run_experiment_2(adult_final_sfm, adult_train_labels, tests=[('neural_net', 'basic', pipeline_basic(MLPClassifier))])
# Out:
# 100%|██████████| 4/4 [00:17<00:00,  4.47s/it]

# %%
madelon_nn_scaled, _ = run_experiment_2(madelon_train_scaled, madelon_train_labels, tests=[('neural_net', 'basic', pipeline_basic(MLPClassifier))])
madelon_nn_ic, _ = run_experiment_2(madelon_final_ic, madelon_train_labels, tests=[('neural_net', 'basic', pipeline_basic(MLPClassifier))])
madelon_nn_rp, _ = run_experiment_2(madelon_final_rp, madelon_train_labels, tests=[('neural_net', 'basic', pipeline_basic(MLPClassifier))])
madelon_nn_pca, _ = run_experiment_2(madelon_final_pca, madelon_train_labels, tests=[('neural_net', 'basic', pipeline_basic(MLPClassifier))])
madelon_nn_sfm, _ = run_experiment_2(madelon_final_sfm, madelon_train_labels, tests=[('neural_net', 'basic', pipeline_basic(MLPClassifier))])
# Out:
# ...
#   0%|          | 0/4 [00:00<?, ?it/s]/opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ...
#   0%|          | 0/4 [00:00<?, ?it/s]/opt/conda/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ...
# 100%|██████████| 4/4 [00:05<00:00,  1.26s/it]

# %%
from matplotlib.cm import viridis_r

# %%
fig, ax = plt.subplots(1, 4, figsize=(20,8))
# adult_nn_scaled = adult_nn_scaled[['f1_test_score', 'f1_train_score', 'n_pcnt']].copy().set_index('n_pcnt')
# adult_nn_gelman = adult_nn_gelman[['f1_test_score', 'f1_train_score', 'n_pcnt']].copy().set_index('n_pcnt')
# adult_nn_ic = adult_nn_ic[['f1_test_score', 'f1_train_score', 'n_pcnt']].copy().set_index('n_pcnt')
# adult_nn_rp = adult_nn_rp[['f1_test_score', 'f1_train_score', 'n_pcnt']].copy().set_index('n_pcnt')
# adult_nn_pca = adult_nn_pca[['f1_test_score', 'f1_train_score', 'n_pcnt']].copy().set_index('n_pcnt')
# adult_nn_sfm = adult_nn_sfm[['f1_test_score', 'f1_train_score', 'n_pcnt']].copy().set_index('n_pcnt')

# adult_nn_scaled.columns = ['scaled f1_test_score', 'scaled f1_train_score']
# adult_nn_gelman.columns = ['gelman f1_test_score', 'gelman f1_train_score']
# adult_nn_ic.columns = ['ic f1_test_score', 'ic f1_train_score']
# adult_nn_rp.columns = ['rp f1_test_score', 'rp f1_train_score']
# adult_nn_pca.columns = ['pca f1_test_score', 'pca f1_train_score']
# adult_nn_sfm.columns = ['sfm f1_test_score', 'sfm f1_train_score']

# adult_nn = pd.merge(adult_nn_scaled, adult_nn_gelman, left_index=True, right_index=True)
# adult_nn = pd.merge(adult_nn, adult_nn_ic, left_index=True, right_index=True)
# adult_nn = pd.merge(adult_nn, adult_nn_rp, left_index=True, right_index=True)
# adult_nn = pd.merge(adult_nn, adult_nn_pca, left_index=True, right_index=True)
# adult_nn = pd.merge(adult_nn, adult_nn_sfm, left_index=True, right_index=True)
adult_nn[[col for col in adult_nn.columns if 'train' in col]].plot(ax=ax[0], cmap=viridis_r, ylim=(0,1))
adult_nn[[col for col in adult_nn.columns if 'test' in col]].plot(ax=ax[1], cmap=viridis_r, ylim=(0,1))


# madelon_nn_scaled = madelon_nn_scaled[['f1_test_score', 'f1_train_score', 'n_pcnt']].copy().set_index('n_pcnt')
# madelon_nn_ic = madelon_nn_ic[['f1_test_score', 'f1_train_score', 'n_pcnt']].copy().set_index('n_pcnt')
# madelon_nn_rp = madelon_nn_rp[['f1_test_score', 'f1_train_score', 'n_pcnt']].copy().set_index('n_pcnt')
# madelon_nn_pca = madelon_nn_pca[['f1_test_score', 'f1_train_score', 'n_pcnt']].copy().set_index('n_pcnt')
# madelon_nn_sfm = madelon_nn_sfm[['f1_test_score', 'f1_train_score', 'n_pcnt']].copy().set_index('n_pcnt')

# madelon_nn_scaled.columns = ['scaled f1_test_score', 'scaled f1_train_score']
# madelon_nn_ic.columns = ['ic f1_test_score', 'ic f1_train_score']
# madelon_nn_rp.columns = ['rp f1_test_score', 'rp f1_train_score']
# madelon_nn_pca.columns = ['pca f1_test_score', 'pca f1_train_score']
# madelon_nn_sfm.columns = ['sfm f1_test_score', 'sfm f1_train_score']

# madelon_nn = pd.merge(madelon_nn_scaled, madelon_nn_ic, left_index=True, right_index=True)
# madelon_nn = pd.merge(madelon_nn, madelon_nn_rp, left_index=True, right_index=True)
# madelon_nn = pd.merge(madelon_nn, madelon_nn_pca, left_index=True, right_index=True)
# madelon_nn = pd.merge(madelon_nn, madelon_nn_sfm, left_index=True, right_index=True)

madelon_nn[[col for col in madelon_nn.columns if 'train' in col]].plot(ax=ax[2], cmap=viridis_r, ylim=(0,1))
madelon_nn[[col for col in madelon_nn.columns if 'test' in col]].plot(ax=ax[3], cmap=viridis_r, ylim=(0,1))

# %%
madelon_nn[[col for col in madelon_nn.columns if 'test' in col]].T[100]
# Out:
# scaled f1_test_score    0.557769
# ic f1_test_score        0.590214
# rp f1_test_score             0.5
# pca f1_test_score       0.807921
# sfm f1_test_score       0.607438
# Name: 100, dtype: object

# %%
madelon_best_cl_2 = pd.read_pickle('data/madelon_best_cl_2.p')
adult_best_cl_14 = pd.read_pickle('data/adult_best_cl_14.p')
adult_best_dr_cl_14_sfm = pd.read_pickle('data/adult_best_dr_cl_14_sfm.p')
madelon_best_df_cl_2_pca = pd.read_pickle('data/madelon_best_df_cl_2_pca.p')
madelon_best_df_cl_3_rp = pd.read_pickle('data/madelon_best_df_cl_3_rp.p')
madelon_best_df_cl_4_ic = pd.read_pickle('data/madelon_best_df_cl_4_ic.p')
madelon_best_df_cl_3_ic = pd.read_pickle('data/madelon_best_df_cl_3_ic.p')

# %%
adult_best_cl_14 = adult_best_cl_14.cluster

# %%
adult_best_dr_cl_14_sfm = adult_best_dr_cl_14_sfm.cluster
madelon_best_df_cl_2_pca = madelon_best_df_cl_2_pca.cluster
madelon_best_df_cl_3_rp = madelon_best_df_cl_3_rp.cluster
madelon_best_df_cl_4_ic = madelon_best_df_cl_4_ic.cluster
madelon_best_df_cl_3_ic = madelon_best_df_cl_3_ic.cluster

# %%
adult_best_cl_14
adult_best_dr_cl_14_sfm

madelon_best_cl_2
madelon_best_df_cl_2_pca
madelon_best_df_cl_3_rp
madelon_best_df_cl_4_ic
madelon_best_df_cl_3_ic

# %%
madelon_nn_madelon_best_cl_2, _        = run_experiment_2(np.array([madelon_best_cl_2]).T, madelon_train_labels, tests=[('neural_net', 'basic', pipeline_basic(MLPClassifier))])
madelon_nn_madelon_best_df_cl_2_pca, _ = run_experiment_2(np.array([madelon_best_df_cl_2_pca]).T, madelon_train_labels, tests=[('neural_net', 'basic', pipeline_basic(MLPClassifier))])
madelon_nn_madelon_best_df_cl_3_rp, _  = run_experiment_2(np.array([madelon_best_df_cl_3_rp]).T, madelon_train_labels, tests=[('neural_net', 'basic', pipeline_basic(MLPClassifier))])
madelon_nn_madelon_best_df_cl_4_ic, _  = run_experiment_2(np.array([madelon_best_df_cl_4_ic]).T, madelon_train_labels, tests=[('neural_net', 'basic', pipeline_basic(MLPClassifier))])
madelon_nn_madelon_best_df_cl_3_ic, _  = run_experiment_2(np.array([madelon_best_df_cl_3_ic]).T, madelon_train_labels, tests=[('neural_net', 'basic', pipeline_basic(MLPClassifier))])
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]/opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ...
# 100%|██████████| 4/4 [00:00<00:00, 11.97it/s]

# %%
adult_nn_adult_best_cl_14, _         = run_experiment_2(np.array([adult_best_cl_14]).T, adult_train_labels, tests=[('neural_net', 'basic', pipeline_basic(MLPClassifier))])
adult_nn_adult_best_dr_cl_14_sfm, _  = run_experiment_2(np.array([adult_best_dr_cl_14_sfm]).T, adult_train_labels, tests=[('neural_net', 'basic', pipeline_basic(MLPClassifier))])
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]/opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ...
# 100%|██████████| 4/4 [00:04<00:00,  1.11s/it]

# %%
fig, ax = plt.subplots(1, 4, figsize=(20,8))
adult_nn_adult_best_cl_14 = adult_nn_adult_best_cl_14[['f1_test_score', 'f1_train_score', 'n_pcnt']].copy().set_index('n_pcnt')
adult_nn_adult_best_dr_cl_14_sfm = adult_nn_adult_best_dr_cl_14_sfm[['f1_test_score', 'f1_train_score', 'n_pcnt']].copy().set_index('n_pcnt')

adult_nn_adult_best_cl_14.columns = ['scaled Full k=14 f1_test_score', 'scaled full k=14 f1_train_score']
adult_nn_adult_best_dr_cl_14_sfm.columns = ['gelman SFM k=14 Tied f1_test_score', 'gelman SFM k=14 Tied f1_train_score']

adult_nn_dr_cl = pd.merge(adult_nn_adult_best_cl_14, adult_nn_adult_best_dr_cl_14_sfm, left_index=True, right_index=True)

adult_nn_dr_cl[[col for col in adult_nn_dr_cl.columns if 'train' in col]].plot(ax=ax[0], cmap=viridis_r, ylim=(0,1))
adult_nn_dr_cl[[col for col in adult_nn_dr_cl.columns if 'test' in col]].plot(ax=ax[1], cmap=viridis_r, ylim=(0,1))


madelon_nn_madelon_best_cl_2 = madelon_nn_madelon_best_cl_2[['f1_test_score', 'f1_train_score', 'n_pcnt']].copy().set_index('n_pcnt')
madelon_nn_madelon_best_df_cl_2_pca = madelon_nn_madelon_best_df_cl_2_pca[['f1_test_score', 'f1_train_score', 'n_pcnt']].copy().set_index('n_pcnt')
madelon_nn_madelon_best_df_cl_3_rp = madelon_nn_madelon_best_df_cl_3_rp[['f1_test_score', 'f1_train_score', 'n_pcnt']].copy().set_index('n_pcnt')
madelon_nn_madelon_best_df_cl_4_ic = madelon_nn_madelon_best_df_cl_4_ic[['f1_test_score', 'f1_train_score', 'n_pcnt']].copy().set_index('n_pcnt')
madelon_nn_madelon_best_df_cl_3_ic = madelon_nn_madelon_best_df_cl_3_ic[['f1_test_score', 'f1_train_score', 'n_pcnt']].copy().set_index('n_pcnt')

madelon_nn_madelon_best_cl_2.columns = ['scaled Spherical k=2 f1_test_score', 'scaled Spherical k=2 f1_train_score']
madelon_nn_madelon_best_df_cl_2_pca.columns = ['pca tied k=2 f1_test_score', 'pca tied k=2 f1_train_score']
madelon_nn_madelon_best_df_cl_3_rp.columns = ['rp diag k=3 f1_test_score', 'rp diag k=3 f1_train_score']
madelon_nn_madelon_best_df_cl_4_ic.columns = ['ica spherical k=4 f1_test_score', 'ica spherical k=4 f1_train_score']
madelon_nn_madelon_best_df_cl_3_ic.columns = ['ica spherical k=3 f1_test_score', 'ica spherical k=3 f1_train_score']

madelon_nn_dr_cl = pd.merge(madelon_nn_madelon_best_cl_2, madelon_nn_madelon_best_df_cl_2_pca, left_index=True, right_index=True)
madelon_nn_dr_cl = pd.merge(madelon_nn_dr_cl, madelon_nn_madelon_best_df_cl_3_rp, left_index=True, right_index=True)
madelon_nn_dr_cl = pd.merge(madelon_nn_dr_cl, madelon_nn_madelon_best_df_cl_4_ic, left_index=True, right_index=True)
madelon_nn_dr_cl = pd.merge(madelon_nn_dr_cl, madelon_nn_madelon_best_df_cl_3_ic, left_index=True, right_index=True)

madelon_nn_dr_cl[[col for col in madelon_nn_dr_cl.columns if 'train' in col]].plot(ax=ax[2], cmap=viridis_r, ylim=(0,1))
madelon_nn_dr_cl[[col for col in madelon_nn_dr_cl.columns if 'test' in col]].plot(ax=ax[3], cmap=viridis_r, ylim=(0,1))

# %%
madelon_nn_dr_cl[[col for col in madelon_nn_dr_cl.columns if 'test' in col]].T[100]
# Out:
# scaled Spherical k=2 f1_test_score    0.562992
# pca tied k=2 f1_test_score            0.603482
# rp diag k=3 f1_test_score             0.600683
# ica spherical k=4 f1_test_score       0.633929
# ica spherical k=3 f1_test_score       0.439655
# Name: 100, dtype: object
